# %%
from pathlib import Path
src = Path('jotoai-home.html')
dst = Path('index.html')
dst.write_text(src.read_text(encoding='utf-8'), encoding='utf-8')
print('copied', dst, 'size', dst.stat().st_size)
